# %%
import pandas as pd
df = pd.read_csv('/Users/silas.rudolf/projects/School/MA/experiments/data/keyword-eval/scores.csv')
df
# Out:
#                   filename  attention_max_precision@2  \
# 0            Bdb001.json_0                        0.5
# 1            Bdb001.json_1                        0.0
# 2            Bdb001.json_2                        0.0
# 3            Bdb001.json_3                        0.5
# 4            Bdb001.json_4                        0.0
# ..                     ...                        ...
# 892  education_9.json_1007                        0.0
# 893  education_9.json_1008                        0.5
# 894  education_9.json_1010                        0.0
# 895  education_9.json_1011                        0.0
# 896  education_9.json_1012                        0.0
#
#      attention_max_precision@3  attention_max_precision@5  \
# 0                         0.33                        0.2
# 1                          NaN                        NaN
# 2                         0.00                        NaN
# 3                         0.33                        0.2
# ...

# %%
df.filter(regex=r'_precision@5').mean().sort_values(ascending=False)
#df[df.drop('filename', axis=1) >0 ].filter(regex=r'_precision@2').mean().sort_values(ascending=False)
# Out:
# keybert_default_precision@5    0.038000
# keybert_mmr_precision@5        0.036667
# attention_mean_precision@5     0.031333
# attention_sum_precision@5      0.031333
# attention_max_precision@5      0.026667
# textrank_precision@5           0.018060
# topicrank_precision@5          0.014765
# positionrank_precision@5       0.014667
# keybert_maxsum_precision@5     0.008247
# frake_precision@5              0.007432
# yake_precision@5               0.001333
# rake_precision@5               0.000000
# dtype: float64

# %%
df.filter(regex=r'_rouge_1_f').mean().sort_values(ascending=False)
# Out:
# keybert_default_rouge_1_f    0.327157
# keybert_mmr_rouge_1_f        0.325619
# yake_rouge_1_f               0.324983
# topicrank_rouge_1_f          0.303924
# positionrank_rouge_1_f       0.300569
# textrank_rouge_1_f           0.293623
# keybert_maxsum_rouge_1_f     0.270825
# attention_mean_rouge_1_f     0.261628
# attention_sum_rouge_1_f      0.260647
# rake_rouge_1_f               0.257057
# attention_max_rouge_1_f      0.250256
# frake_rouge_1_f              0.242486
# dtype: float64

# %%
import pandas as pd
df_batch = pd.read_csv('/Users/silas.rudolf/projects/School/MA/experiments/data/keyphrase-eval/batch_scores.csv')
df_full = pd.read_csv('/Users/silas.rudolf/projects/School/MA/experiments/data/keyphrase-eval/full_scores.csv')

# %%
df_batch
# Out:
#                    filename  cnn_14000_rouge_1_mean_r  \
# 0             Bdb001.json_0                  0.500000
# 1             Bdb001.json_1                  0.730769
# 2             Bdb001.json_2                  0.587500
# 3             Bdb001.json_3                  0.467611
# 4             Bdb001.json_4                  0.437500
# ...                     ...                       ...
# 1008  education_9.json_1008                  0.677632
# 1009  education_9.json_1009                  0.712727
# 1010  education_9.json_1010                  0.627312
# 1011  education_9.json_1011                  0.822129
# 1012  education_9.json_1012                  0.802381
#
#       cnn_14000_rouge_1_mean_p  cnn_14000_rouge_1_mean_f  \
# 0                     0.823569                  0.612142
# 1                     0.500462                  0.584589
# 2                     0.622326                  0.586653
# 3                     0.767026                  0.570674
# ...

# %%
df_batch.filter(regex=r'_mean_c').mean().sort_values(ascending=False)
# Out:
# xsum_32000_rouge_1_mean_f    0.609786
# cnn_35000_rouge_1_mean_f     0.600843
# cnn_14000_rouge_1_mean_f     0.592307
# xsum_10000_rouge_1_mean_f    0.585372
# dtype: float64

# %%
df_batch.filter(regex=r'_mean_p').mean().sort_values(ascending=False)
# Out:
# xsum_32000_rouge_1_mean_p    0.670201
# cnn_35000_rouge_1_mean_p     0.636745
# xsum_10000_rouge_1_mean_p    0.627487
# cnn_14000_rouge_1_mean_p     0.620897
# dtype: float64

# %%
df_batch.filter(regex=r'_mean_r').mean().sort_values(ascending=False)
# Out:
# cnn_35000_rouge_1_mean_r     0.690983
# cnn_14000_rouge_1_mean_r     0.686113
# xsum_32000_rouge_1_mean_r    0.660522
# xsum_10000_rouge_1_mean_r    0.655755
# dtype: float64

# %%
df_full
# Out:
#                    filename  cnn_14000_rouge_1_r  cnn_14000_rouge_1_p  \
# 0             Bdb001.json_0             0.862069             1.000000
# 1             Bdb001.json_1             1.000000             1.000000
# 2             Bdb001.json_2             0.775000             0.632653
# 3             Bdb001.json_3             1.000000             1.000000
# 4             Bdb001.json_4             0.846154             0.488889
# ...                     ...                  ...                  ...
# 1008  education_9.json_1008             0.877193             0.666667
# 1009  education_9.json_1009             0.854545             0.796610
# 1010  education_9.json_1010             1.000000             1.000000
# 1011  education_9.json_1011             0.980392             0.393701
# 1012  education_9.json_1012             0.714286             0.888889
#
#       cnn_14000_rouge_1_f  cnn_35000_rouge_1_r  cnn_35000_rouge_1_p  \
# ...

# %%
df_full.filter(regex=r'_f').mean().sort_values(ascending=False)
# Out:
# xsum_32000_rouge_1_f    0.914947
# cnn_35000_rouge_1_f     0.903947
# cnn_14000_rouge_1_f     0.760504
# xsum_10000_rouge_1_f    0.687051
# dtype: float64

# %%
df_full.filter(regex=r'_p').mean().sort_values(ascending=False)
# Out:
# xsum_32000_rouge_1_p    0.916402
# cnn_35000_rouge_1_p     0.900563
# cnn_14000_rouge_1_p     0.757854
# xsum_10000_rouge_1_p    0.732991
# dtype: float64

# %%
df_full.filter(regex=r'1_r').mean().sort_values(ascending=False)
# Out:
# xsum_32000_rouge_1_r    0.935316
# cnn_35000_rouge_1_r     0.934886
# cnn_14000_rouge_1_r     0.824983
# xsum_10000_rouge_1_r    0.721031
# dtype: float64
